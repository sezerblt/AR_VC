# %% [markdown]
# <a href="https://colab.research.google.com/github/sezerblt/AR_VC/blob/master/Colaboratory'ye_Ho%C5%9F_Geldiniz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Depoyu klonla

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/yolov8_tracking.git

# %% [markdown]
# 2.bağımlılıkların kurulumu

# %%
# %pip install -qr yolov8_tracking/requirements.txt
# %pip install thop

# %% [markdown]
# 3. PyTorch ile TPU import etme

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch")
print(f"torch version: {torch.__version__}")
print(f"device:{torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'} ")
if torch.cuda.is_available():
  print(f"device: GPU")
else:
  print(f"device: CPU or CPU")

# %% [markdown]
# 4.klasor git

# %%
# %cd /content/yolov8_tracking

# %% [markdown]
# 5.Depodan test videosu al.

# %%
# !wget -nc https://github.com/mikel-brostrom/yolov8_tracking/releases/download/v.2.0/test.avi

# %% [markdown]
# 6.Ilk 5 saniyesini çıkar

# %%
# 5 saniyelik video karelerini çıkarın

# !yes | ffmpeg -ss 00:00:00 -i pedestrian.mp4 -t 00:00:05 -vf fps=30 out_pedestrian.avi

# %% [markdown]
# 7. video yu not defterinde dosya da tutmak için kaydet.
# Gerçek zamanlı olarak izlemek için
# * --show-vid
#
# bayrağını eklendi

# %% [markdown]
# !python  track.py
#
# --yolo-weights  yolov8s.pt
#
# --reid-weights  osnet_x0_25_msmt17.pt
#
# --source  out.avi
#
# --save-vid

# %%
# !python track.py --yolo-weights yolov8s.pt --reid-weights osnet_x0_25_msmt17.pt --source out_pedestrian.avi --save-vid

# %% [markdown]
# #Calistir
# 8.Video dosyasını Google Colab tarafından desteklenen bir formatta sıkıştır.

# %%
# !ffmpeg -i /content/yolov8_tracking/runs/track/exp/out_pedestrian.mp4 -vf fps=30 -vcodec libx264 output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %% [markdown]
# 9.Dosya içeriğini data_url içine alalim

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# 10.HTML ile göster

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
